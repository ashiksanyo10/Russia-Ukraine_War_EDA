# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# %matplotlib inline

# %%
df=pd.read_csv("../input/2022-ukraine-russian-war/russia_losses_equipment.csv",parse_dates=['date']) #equipment data

df_p=pd.read_csv("../input/2022-ukraine-russian-war/russia_losses_personnel.csv") #persons

# %%
df.info()

# %%
df.head()

# %%
df.tail()

# %%
df.isna().sum()

# %%
df[["special equipment"]]=df[["special equipment"]].fillna(method='bfill')

# %%
df["mobile SRBM system"]=df["mobile SRBM system"].fillna(4)

# %%
df.isna().sum()

# %%
var =["aircraft","helicopter","tank","APC","field artillery","MRL","military auto","fuel tank","drone","naval ship","anti-aircraft warfare","special equipment"]

# %% [markdown]
# # **# Graphical plot of equipments destroyed on a daily basis**

# %%
for i in var:
    
    fig=px.line(df,x="date",y=i)
    fig.show()

# %%
px.pie(df[var],values=df[var].sum(),names=var)

# %%
df_p.info()

# %%
df_p.head()

# %%
df_p.tail()

# %%
df_p.isna().sum()

# %%
px.line(df_p,x='date',y='personnel')

# %% [markdown]
# # Insights and Conclusion

# %%
print("Total equipments destroyed till date: ")
print("-"*40)
for i in var:
    print(i,df[i].max())
    
print("-"*40)
print("Total War casualty till date: ")
print(df_p["personnel"].max())
